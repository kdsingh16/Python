# %%
import pandas as pd 
import statistics as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sb

# %%
car=pd.read_csv("DS1_C5_S1_Descriptive_Analysis_Practice_Car_Data.csv")
car.head()
# Out:
#    Sl. No.  Make      Model  Variant  Displacement  Cylinders  \
# 0        0  Tata  Nano Genx       Xt         624.0        2.0
# 1        1  Tata  Nano Genx       Xe         624.0        2.0
# 2        2  Tata  Nano Genx  Emax Xm         624.0        2.0
# 3        3  Tata  Nano Genx      Xta         624.0        2.0
# 4        4  Tata  Nano Genx       Xm         624.0        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#     Engine_Location  ... Leather_Wrapped_Steering  Automatic_Headlamps  \
# 0  Rear, Transverse  ...                      NaN                  NaN
# ...

# %%
car1 = car.iloc[:,[1,4,11,18,19,72]]
car1.head()
# Out:
#    Make  Displacement  Fuel_Tank_Capacity_litre  City_Mileage_km_litre  \
# 0  Tata         624.0                      24.0                   23.6
# 1  Tata         624.0                      24.0                   23.6
# 2  Tata         624.0                      15.0                    NaN
# 3  Tata         624.0                      24.0                   23.6
# 4  Tata         624.0                      24.0                   23.6
#
#    Highway_Mileage_km_litre  Minimum_Turning_Radius
# 0                       NaN                     4.0
# 1                       NaN                     4.0
# 2                       NaN                     4.0
# 3                       NaN                     4.0
# 4                       NaN                     4.0

# %%
car2=car1.dropna()
car2.head(2)
# Out:
#      Make  Displacement  Fuel_Tank_Capacity_litre  City_Mileage_km_litre  \
# 6  Datsun         799.0                      28.0                  21.38
# 7  Datsun         799.0                      28.0                  21.38
#
#    Highway_Mileage_km_litre  Minimum_Turning_Radius
# 6                      24.0                     4.7
# 7                      24.0                     4.7

# %% [markdown]
# ## Task 1

# %%
#maruti 
m=car2[(car2.Make=='Maruti Suzuki')]
m=m.drop('Make',axis=1)
m.head(2)
# Out:
#     Displacement  Fuel_Tank_Capacity_litre  City_Mileage_km_litre  \
# 24        1196.0                      40.0                   12.0
# 25        1196.0                      40.0                   12.0
#
#     Highway_Mileage_km_litre  Minimum_Turning_Radius
# 24                      15.0                     4.5
# 25                      15.0                     4.5

# %%
mean=[]
median=[]
std=[]
cv=[]
for col in m.head():
    col_mean=m[col].mean()
    mean.append(col_mean)
    col_median=m[col].median()
    median.append(col_median)
    col_std=m[col].std()
    std.append(col_std)
    cv.append(col_std/col_mean*100)
    
row_head=['Mean','Median','standard deviation','Cofefficient of variance']
col_names=list(m.columns)
central=pd.DataFrame([mean,median,std,cv],columns=col_names,index=[1,2,3,4])
central.insert(0,'Measures',row_head)
central.round(2)
# Out:
#                    Measures  Displacement  Fuel_Tank_Capacity_litre  \
# 1                      Mean       1081.68                     38.48
# 2                    Median        998.00                     35.00
# 3        standard deviation        147.55                      5.36
# 4  Cofefficient of variance         13.64                     13.93
#
#    City_Mileage_km_litre  Highway_Mileage_km_litre  Minimum_Turning_Radius
# 1                  18.77                     20.67                    4.77
# 2                  20.00                     22.00                    4.70
# 3                   4.39                      3.33                    0.28
# 4                  23.39                     16.11                    5.80

# %%
#Toyota
toyota=car2[(car2.Make=='Toyota')]
toyota=toyota.drop('Make',axis=1)
toyota.head(2)
# Out:
#     Displacement  Fuel_Tank_Capacity_litre  City_Mileage_km_litre  \
# 87        1197.0                      45.0                   15.1
# 88        1197.0                      45.0                   15.1
#
#     Highway_Mileage_km_litre  Minimum_Turning_Radius
# 87                     17.71                     4.8
# 88                     18.16                     4.8

# %%
mean=[]
median=[]
std=[]
cv=[]
for col in toyota.head():
    col_mean=toyota[col].mean()
    mean.append(col_mean)
    col_median=toyota[col].median()
    median.append(col_median)
    col_std=toyota[col].std()
    std.append(col_std)
    cv.append(col_std/col_mean*100)
    
row_head=['Mean','Median','standard deviation','Cofefficient of variance']
col_names=list(toyota.columns)
central=pd.DataFrame([mean,median,std,cv],columns=col_names,index=[1,2,3,4])
central.insert(0,'Measures',row_head)
central.round(2)
# Out:
#                    Measures  Displacement  Fuel_Tank_Capacity_litre  \
# 1                      Mean       1723.68                     53.22
# 2                    Median       1364.00                     45.00
# 3        standard deviation        729.16                     15.97
# 4  Cofefficient of variance         42.30                     30.01
#
#    City_Mileage_km_litre  Highway_Mileage_km_litre  Minimum_Turning_Radius
# 1                  15.73                     18.45                    5.08
# 2                  15.10                     17.94                    4.80
# 3                   4.14                      4.49                    0.41
# 4                  26.34                     24.33                    8.16

# %%
#Mahindra
mahindra=car2[(car2.Make=='Mahindra')]
mahindra=mahindra.drop('Make',axis=1)
mahindra.head(2)
# Out:
#      Displacement  Fuel_Tank_Capacity_litre  City_Mileage_km_litre  \
# 212        1461.0                      50.0                   18.0
# 213        1461.0                      50.0                   18.0
#
#      Highway_Mileage_km_litre  Minimum_Turning_Radius
# 212                     20.08                    5.25
# 213                     20.08                    5.25

# %%
mean=[]
median=[]
std=[]
cv=[]
for col in mahindra.head():
    col_mean=mahindra[col].mean()
    mean.append(col_mean)
    col_median=mahindra[col].median()
    median.append(col_median)
    col_std=mahindra[col].std()
    std.append(col_std)
    cv.append(col_std/col_mean*100)
    
row_head=['Mean','Median','standard deviation','Cofefficient of variance']
col_names=list(mahindra.columns)
central=pd.DataFrame([mean,median,std,cv],columns=col_names,index=[1,2,3,4])
central.insert(0,'Measures',row_head)
central.round(2)
# Out:
#                    Measures  Displacement  Fuel_Tank_Capacity_litre  \
# 1                      Mean       1922.70                     55.62
# 2                    Median       2179.00                     60.00
# 3        standard deviation        499.53                     10.99
# 4  Cofefficient of variance         25.98                     19.76
#
#    City_Mileage_km_litre  Highway_Mileage_km_litre  Minimum_Turning_Radius
# 1                  13.70                     16.73                    5.46
# 2                  12.35                     15.45                    5.50
# 3                   3.76                      3.37                    0.26
# 4                  27.46                     20.14                    4.75

# %%
maruticar=list(m['Displacement'])
toyotacar=list(toyota['Displacement'])
mahindracar=list(mahindra['Displacement'])

# %%
Fig=plt.figure(figsize=(10,5))
plt.boxplot([maruticar,toyotacar,mahindracar],vert=0,showmeans= True)
plt.yticks([1,2,3],['Maruti suzuki','Toyota','Mahindra']);

# %% [markdown]
# Conclusion:- After my analysing the data i can see that toyota car is right skewed and it has also maximum number of outliers
#               and mahindra car is left skewed and their is no outliers

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### toyota

# %%
plt.figure(figsize=(10,4))
corr1=toyota['Highway_Mileage_km_litre'].corr(toyota['Displacement']).round(2)
plt.subplot(131)
plt.title('mg vs disp')

plt.scatter(toyota['Highway_Mileage_km_litre'],toyota['Displacement'],color='orange',label='r ='+str(corr1))
plt.title('mg vs disp')
plt.xlabel('mg')
plt.ylabel('disp')
plt.legend()


corr2=toyota['Highway_Mileage_km_litre'].corr(toyota['Minimum_Turning_Radius']).round(2)
plt.subplot(132)
plt.title('mg vs mini')

plt.scatter(toyota['Highway_Mileage_km_litre'],toyota['Minimum_Turning_Radius'],color='orange',label='r ='+str(corr2))
plt.title('mg vs mini')
plt.xlabel('mg')
plt.ylabel('mini')
plt.legend()


corr3=toyota['Highway_Mileage_km_litre'].corr(toyota['Fuel_Tank_Capacity_litre']).round(2)
plt.subplot(133)
plt.title('mg vs fuel')

plt.scatter(toyota['Highway_Mileage_km_litre'],toyota['Fuel_Tank_Capacity_litre'],color='orange',label='r ='+str(corr3))
plt.title('mg vs fuel')
plt.xlabel('mg')
plt.ylabel('fuel')
plt.legend()

# %% [markdown]
# ## mahindra

# %%
plt.figure(figsize=(10,4))
corr1=mahindra['Highway_Mileage_km_litre'].corr(mahindra['Displacement']).round(2)
plt.subplot(131)
plt.title('mg vs disp')

plt.scatter(mahindra['Highway_Mileage_km_litre'],mahindra['Displacement'],color='red',label='r ='+str(corr1))
plt.title('mg vs disp')
plt.xlabel('mg')
plt.ylabel('disp')
plt.legend()


corr2=mahindra['Highway_Mileage_km_litre'].corr(mahindra['Minimum_Turning_Radius']).round(2)
plt.subplot(132)
plt.title('mg vs mini')

plt.scatter(mahindra['Highway_Mileage_km_litre'],mahindra['Minimum_Turning_Radius'],color='red',label='r ='+str(corr2))
plt.title('mg vs mini')
plt.xlabel('mg')
plt.ylabel('mini')
plt.legend()


corr3=mahindra['Highway_Mileage_km_litre'].corr(mahindra['Fuel_Tank_Capacity_litre']).round(2)
plt.subplot(133)
plt.title('mg vs fuel')

plt.scatter(mahindra['Highway_Mileage_km_litre'],mahindra['Fuel_Tank_Capacity_litre'],color='red',label='r ='+str(corr3))
plt.title('mg vs fuel')
plt.xlabel('mg')
plt.ylabel('fuel')
plt.legend()

# %% [markdown]
# ### Maruti suzuki

# %%
plt.figure(figsize=(10,4))
corr1=m['Highway_Mileage_km_litre'].corr(m['Displacement']).round(2)
plt.subplot(131)
plt.title('mg vs disp')

plt.scatter(m['Highway_Mileage_km_litre'],m['Displacement'],color='green',label='r ='+str(corr1))
plt.title('mg vs disp')
plt.xlabel('mg')
plt.ylabel('disp')
plt.legend()


corr2=m['Highway_Mileage_km_litre'].corr(m['Minimum_Turning_Radius']).round(2)
plt.subplot(132)
plt.title('mg vs mini')

plt.scatter(m['Highway_Mileage_km_litre'],m['Minimum_Turning_Radius'],color='green',label='r ='+str(corr2))
plt.title('mg vs mini')
plt.xlabel('mg')
plt.ylabel('mini')
plt.legend()


corr3=m['Highway_Mileage_km_litre'].corr(m['Fuel_Tank_Capacity_litre']).round(2)
plt.subplot(133)
plt.title('mg vs fuel')

plt.scatter(m['Highway_Mileage_km_litre'],m['Fuel_Tank_Capacity_litre'],color='green',label='r ='+str(corr3))
plt.title('mg vs fuel')
plt.xlabel('mg')
plt.ylabel('fuel')
plt.legend()
